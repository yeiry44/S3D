# %%
import pandas as pd
pd.__version__
import IPython.display as ipd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
info = pd.read_csv('/Users/yeiry/Downloads/research - Sheet3 (3).csv')
pd.options.display.max_rows =500  #change number of rows
#use loc to return certain rows
#info is a dataframe already so no need for dataframe

df = info.copy() #copy of it
info
# Out:
#      algorithm microphone_distance   signal source_position  \
# 0          NaN                 NaN      NaN             NaN
# 1         CSSM     binaural (18cm)     50Hz       0 degrees
# 2         CSSM     binaural (18cm)     50Hz      63 degrees
# 3         CSSM     binaural (18cm)     50Hz      45 degrees
# 4         CSSM     binaural (18cm)    440Hz       0 degrees
# 5         CSSM     binaural (18cm)    440Hz      63 degrees
# 6         CSSM     binaural (18cm)    440Hz      45 degrees
# 7         CSSM     binaural (18cm)    880Hz       0 degrees
# 8         CSSM     binaural (18cm)    880Hz      63 degrees
# 9         CSSM     binaural (18cm)    880Hz      45 degrees
# 10        CSSM     binaural (18cm)  vehicle       0 degrees
# 11        CSSM     binaural (18cm)  vehicle      63 degrees
# 12        CSSM     binaural (18cm)  vehicle      45 degrees
# 13        CSSM        stereo (2cm)     50Hz       0 degrees
# 14        CSSM        stereo (2cm)     50Hz      63 degrees
# ...

# %%
df=df[df.original_azimuth>=0]
df.original_azimuth.unique()
# Out:
# array([ 0., 63., 45.])

# %%
_df=df.loc[(df['signal'] == '50Hz') & (df['microphone_distance'] == 'binaural (18cm)') 
           & (df['source_position'] == '63 degrees')]
#_df=df.loc[(df['source_position'] == '63 degrees')].signal.unique()
_df
# Out:
#      algorithm microphone_distance signal source_position  recovered_azimuth  \
# 2         CSSM     binaural (18cm)   50Hz      63 degrees              270.0
# 27       MUSIC     binaural (18cm)   50Hz      63 degrees                2.0
# 52   NormMUSIC     binaural (18cm)   50Hz      63 degrees              173.0
# 77         SRP     binaural (18cm)   50Hz      63 degrees              153.0
# 102       TOPS     binaural (18cm)   50Hz      63 degrees              335.0
# 127      WAVES     binaural (18cm)   50Hz      63 degrees               90.0
#
#      error  original_azimuth
# 2    153.4              63.0
# 27    61.4              63.0
# 52   109.6              63.0
# 77    89.6              63.0
# 102   88.4              63.0
# 127   26.5              63.0

# %%
df.signal.unique()
df.error=df.error.astype(float)

# %%
plt.figure(figsize=(15,5))
ax = sns.barplot(x="original_azimuth", y="error", hue="algorithm", data=df)
ax
# Out:
# <AxesSubplot:xlabel='original_azimuth', ylabel='error'>

# %%
plt.figure(figsize=(15,5))
ax = sns.barplot(x="microphone_distance", y="error", hue="algorithm", data=df)
ax
# Out:
# <AxesSubplot:xlabel='microphone_distance', ylabel='error'>

# %%
plt.figure(figsize=(15,5))
ax = sns.barplot(x="signal", y="error", hue="algorithm", data=df)
ax
# Out:
# <AxesSubplot:xlabel='signal', ylabel='error'>

# %%
df.microphone_distance.unique()
# Out:
# array(['binaural (18cm)', 'stereo (2cm)'], dtype=object)

# %%
_df.plot(kind = 'scatter', x = 'original_azimuth', y = 'recovered_azimuth')
plt.show()

# %%
_df=df.loc[(df['signal'] == '50Hz') & (df['microphone_distance'] == 'binaural (18cm)')]
_df
# Out:
#      algorithm microphone_distance signal source_position  recovered_azimuth  \
# 1         CSSM     binaural (18cm)   50Hz       0 degrees               90.0
# 2         CSSM     binaural (18cm)   50Hz      63 degrees              270.0
# 3         CSSM     binaural (18cm)   50Hz      45 degrees               90.0
# 26       MUSIC     binaural (18cm)   50Hz       0 degrees              163.0
# 27       MUSIC     binaural (18cm)   50Hz      63 degrees                2.0
# 28       MUSIC     binaural (18cm)   50Hz      45 degrees              337.0
# 51   NormMUSIC     binaural (18cm)   50Hz       0 degrees              179.0
# 52   NormMUSIC     binaural (18cm)   50Hz      63 degrees              173.0
# 53   NormMUSIC     binaural (18cm)   50Hz      45 degrees              338.0
# 76         SRP     binaural (18cm)   50Hz       0 degrees              178.0
# 77         SRP     binaural (18cm)   50Hz      63 degrees              153.0
# ...
